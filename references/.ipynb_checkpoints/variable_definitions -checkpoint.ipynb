# %% [markdown]
# | 原始變數名稱 | 變數描述 | 測量方式 / 單位 | 包含樣本數 (n) |
# | :--- | :--- | :--- | :--- |
# | **WhatIsYourSex** | 受訪者的生理性別 | 類別變數：1 = 女性 (Female), 2 = 男性 (Male) | 13,991 |
# | **HowMuchDoYouWeighWithoutShoesInKG** | 受訪者不穿鞋的體重 | 連續變數：公斤 (kg) | 13,062 (排除缺失後) |
# | **alcohol_binary** | 過去 30 天內的飲酒狀態 | 二元變數：0 = 無飲酒, 1 = 有飲酒 | 12,669 (排除缺失後) |
